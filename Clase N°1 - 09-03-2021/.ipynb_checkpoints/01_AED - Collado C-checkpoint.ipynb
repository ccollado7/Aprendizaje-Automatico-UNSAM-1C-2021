# %% [markdown]
# # Análisis Exploratorio de Datos

# %% [markdown]
# ## Introducción

# %% [markdown]
# Uno de los primeros pasos a la hora de realizar un proyecto que involucre el análisis de datos es explorar y visualizar los datos. El objetivo principal es obtener información sobre el contenido de los datos, ayudar a enmarcar las preguntas que haremos y detectar posibles vías para avanzar en las respuestas a estas preguntas.

# %% [markdown]
# Trabajaremos con un conjunto de datos clásico para Machine Learning, que consiste en datos de alojamiento para distritos en el estado de California, EE. UU. De hecho, usaremos una versión ligeramente modificada, preparada por Aurélien Géron.

# %% [markdown]
# **Plan**
#
# La idea para hoy y para el jueves es dar los primeros pasos en la lista que hemos visto:
#
# 1. Obtención de los datos.
#
# 2. Exploración y visualización de los datos para obtener información.
#      * ¿Qué tipo de preguntas podemos abordar con este conjunto de datos?
#
#      * ¿Necesitamos datos adicionales?
#
#
# 3. Definición del proyecto.
#
# 4. Preprocesamiento. Preparación de los datos para los algoritmos de Machine Learning (El **jueves**).
#
# 5. Selección de modelo, entrenamiento, puesta a punto, ... (**Jueves**).

# %% [markdown]
# ## Celdas preparatorias

# %% [markdown]
# Antes que nada, corramos algunas celdas de código para prepararnos. Mucho de lo que viene a continuación está sacado del libro de Aurélien Geron, y su [repo de GitHub](https://github.com/ageron/handson-ml2), que recomendamos.

# %%
# Python ≥3.5 is required
import sys
assert sys.version_info >= (3, 5)

# Scikit-Learn ≥0.20 is required
import sklearn
assert sklearn.__version__ >= "0.20"

# Common imports
import numpy as np
import os

# To plot pretty figures
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline
mpl.rc('axes', labelsize=14)
mpl.rc('xtick', labelsize=12)
mpl.rc('ytick', labelsize=12)

# Where to save the figures
PROJECT_ROOT_DIR = "."
CHAPTER_ID = "01_AED"
IMAGES_PATH = os.path.join(PROJECT_ROOT_DIR, "images", CHAPTER_ID)
os.makedirs(IMAGES_PATH, exist_ok=True)

def save_fig(fig_id, tight_layout=True, fig_extension="png", resolution=300):
    path = os.path.join(IMAGES_PATH, fig_id + "." + fig_extension)
    print("Saving figure", fig_id)
    if tight_layout:
        plt.tight_layout()
    plt.savefig(path, format=fig_extension, dpi=resolution)

# Ignore useless warnings (see SciPy issue #5998)
import warnings
warnings.filterwarnings(action="ignore", message="^internal gelsd")

# %% [markdown]
# ## Obtención de los datos

# %% [markdown]
# El primer paso es hacerse con el conjunto de datos. Un archivo `csv` está disponible en el repositorio del curso, así que simplemente definimos la ruta desde la cual leeremos el archivo.

# %%
HOUSING_PATH = r"C:\Users\User\Repositorios\Aprendizaje Automatico-UNSAM 1C 2021\Clase N°1 - 09-03-2021\housing.csv"

# %% [markdown]
# Como estoy utilizando en local (no estoy utilizando google colab) elimine algunas celdas y realizo la lectura directa

# %%
import pandas as pd

# %%
housing = pd.read_csv(HOUSING_PATH)

# %% [markdown]
# ## Exploración rápida de los datos

# %% [markdown]
# Ahora tenemos los datos en un formato muy práctico (y de uso común), una instancia de `pandas.DataFrame`.
#
# Si no estás familiarizado con `Pandas`, veremos formas muy básicas de ver el contenido de una tabla. Acordate que siempre se puede agregar "?" A un objeto o método para acceder a su documentación (por ejemplo, `housing?` o `housing.head?`).

# %% [markdown]
# ***
#
# **1.** El método `.info` da información básica del contenido de cada columna.

# %%
#Ayuda sobre el metodo head()

housing.head?

# %%
housing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %% [markdown]
# Vemos que hay **20640** entradas, con 10 columnas cada una. A excepción de `ocean_proximity`, todas las columnas son números (`float64`). Además, faltan algunas entradas en la columna `total_bedrooms`.

# %% [markdown]
# Cada una de estas filas corresponde a un distrito de California. En la analogía del ejemplo de las acciones, cada fila es un momento en el tiempo en el que se evalúa el precio de las acciones de *Tech1*.

# %% [markdown]
# ***
#
# **2.** Para ver las primeras líneas de la tabla, se usa el método `head`, que acepta un argumento optional para indicar cuántas líneas mostrar.

# %%
housing.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %% [markdown]
# **Nota**: se puede acceder al nombre de las columnas con el atributo de `columns`.

# %%
print(housing.columns)
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value', 'ocean_proximity'],
#       dtype='object')

# %% [markdown]
# Veamos un poco más de cerca `ocean_proximity`. ¿Qué valores toma? (**Nota**: se puede acceder a las columnas como atributos del `DataFrame` o con una sintaxis similar a la de un diccionario. En otras palabras, los dos comandos de la celda siguiente son equivalentes).

# %%
print(housing['ocean_proximity'].unique())
print(housing.ocean_proximity.unique())
# Out:
# ['NEAR BAY' '<1H OCEAN' 'INLAND' 'NEAR OCEAN' 'ISLAND']
# ['NEAR BAY' '<1H OCEAN' 'INLAND' 'NEAR OCEAN' 'ISLAND']

# %% [markdown]
# Podemos dar un paso más y ver cuántas veces aparece cada valor.

# %%
print(housing.ocean_proximity.value_counts())
# Out:
# <1H OCEAN     9136
# INLAND        6551
# NEAR OCEAN    2658
# NEAR BAY      2290
# ISLAND           5
# Name: ocean_proximity, dtype: int64

# %%
# Or a normalized version
print(housing.ocean_proximity.value_counts(normalize=True))
# Out:
# <1H OCEAN     0.442636
# INLAND        0.317393
# NEAR OCEAN    0.128779
# NEAR BAY      0.110950
# ISLAND        0.000242
# Name: ocean_proximity, dtype: float64

# %% [markdown]
# ***
#
# **3.** Para las columnas numéricas, podemos obtener estadísticos descriptivos simples usando el método `.describe`.

# %%
housing.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20640.000000  20640.000000        20640.000000  20640.000000
# mean    -119.569704     35.631861           28.639486   2635.763081
# std        2.003532      2.135952           12.585558   2181.615252
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1447.750000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20433.000000  20640.000000  20640.000000   20640.000000
# mean       537.870553   1425.476744    499.539680       3.870671
# std        421.385070   1132.462122    382.329753       1.899822
# min          1.000000      3.000000      1.000000       0.499900
# 25%        296.000000    787.000000    280.000000       2.563400
# 50%        435.000000   1166.000000    409.000000       3.534800
# 75%        647.000000   1725.000000    605.000000       4.743250
# max       6445.000000  35682.000000   6082.000000      15.000100
#
#        median_house_value
# count        20640.000000
# mean        206855.816909
# std         115395.615874
# min          14999.000000
# 25%         119600.000000
# 50%         179700.000000
# 75%         264725.000000
# max         500001.000000

# %% [markdown]
#  **Nota 1**: este método excluye automáticamente las entradas vacías o `NaN` para el cálculo. Vean la entrada `count` de la columna `total_bedrooms`.
#
#  **Nota 2**: se puede ajustar qué percentiles se calculan usando el argumento `percentiles` del método `describe`.

# %% [markdown]
# ***
# **4.** Podemos ordenar la tabla para ver los distritos en los que alguna columna toma valores extremos.

# %%
housing.sort_values(by='median_income', ascending=False)
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 4352     -118.37     34.10                37.0        407.0            67.0
# 10673    -117.85     33.62                13.0       5192.0           658.0
# 8849     -118.40     34.08                52.0       3815.0           439.0
# 4606     -118.33     34.07                52.0       1482.0           171.0
# 5257     -118.49     34.06                42.0       2861.0           360.0
# ...          ...       ...                 ...          ...             ...
# 3249     -119.99     36.09                23.0        333.0            92.0
# 3258     -122.89     39.42                16.0        411.0           114.0
# 6343     -117.75     34.06                52.0         62.0             9.0
# 5213     -118.28     33.93                52.0        117.0            33.0
# 20091    -120.19     38.07                43.0        102.0            19.0
#
#        population  households  median_income  median_house_value  \
# 4352        100.0        47.0        15.0001            500001.0
# 10673      1865.0       662.0        15.0001            500001.0
# 8849       1266.0       413.0        15.0001            500001.0
# 4606        531.0       161.0        15.0001            500001.0
# 5257        829.0       310.0        15.0001            500001.0
# ...           ...         ...            ...                 ...
# 3249        198.0        55.0         0.4999            100000.0
# 3258         26.0        19.0         0.4999             73500.0
# 6343         44.0        16.0         0.4999            112500.0
# 5213         74.0        45.0         0.4999             90600.0
# 20091        44.0        13.0         0.4999            162500.0
#
#       ocean_proximity
# 4352        <1H OCEAN
# 10673       <1H OCEAN
# 8849        <1H OCEAN
# 4606        <1H OCEAN
# 5257        <1H OCEAN
# ...               ...
# 3249           INLAND
# 3258           INLAND
# 6343           INLAND
# 5213        <1H OCEAN
# 20091          INLAND
#
# [20640 rows x 10 columns]

# %% [markdown]
# Tal vez ya identificaron algunos comportamientos patológicos, pero nos guardamos un análisis más detallado para que se diviertan el jueves.

# %% [markdown]
# ***
#
# **5.** Podemos agrupar entradas en función del valor de una variable determinada. Esto es útil para un análisis rápido de los datos.

# %% [markdown]
# Por ejemplo, veamos cómo cambian los valores medios de las columnas con la variable `ocean_proximity`.

# %%
housing.groupby(by='ocean_proximity').mean()
# Out:
#                   longitude   latitude  housing_median_age  total_rooms  \
# ocean_proximity
# <1H OCEAN       -118.847766  34.560577           29.279225  2628.343586
# INLAND          -119.732990  36.731829           24.271867  2717.742787
# ISLAND          -118.354000  33.358000           42.400000  1574.600000
# NEAR BAY        -122.260694  37.801057           37.730131  2493.589520
# NEAR OCEAN      -119.332555  34.738439           29.347254  2583.700903
#
#                  total_bedrooms   population  households  median_income  \
# ocean_proximity
# <1H OCEAN            546.539185  1520.290499  517.744965       4.230682
# INLAND               533.881619  1391.046252  477.447565       3.208996
# ISLAND               420.400000   668.000000  276.600000       2.744420
# NEAR BAY             514.182819  1230.317467  488.616157       4.172885
# NEAR OCEAN           538.615677  1354.008653  501.244545       4.005785
#
#                  median_house_value
# ocean_proximity
# <1H OCEAN             240084.285464
# INLAND                124805.392001
# ISLAND                380440.000000
# NEAR BAY              259212.311790
# NEAR OCEAN            249433.977427

# %% [markdown]
# ***
#
# **6.** Por último, pero no por eso menos importante, podemos calcular estadísticos que involucran más de una variable. El más común es el coeficiente de correlación de Pearson.

# %% [markdown]
# Todavía no estamos para dar una definición formal, pero digamos que el coeficiente de Pearson de dos variables $X$ e $Y$, que llamamos $\hat{\rho_{XY}}$, es un _estimador_ del coeficiente de correlación poblacional:
#
# $$
# \hat{\rho_{XY}} = r = \frac{\hat{\mathrm{cov}}_{XY}}{\hat{\sigma}_X \hat{\sigma}_Y}\;\;,
# $$
# donde
#
# $$
# \hat{\sigma}_X^2 = \frac{1}{N - 1}\sum_{i=1}^N (x_i - \bar{X})^2\;\;,
# $$
# $$
# \hat{\mathrm{cov}}_{XY} = \frac{1}{N - 1}\sum_{i=1}^N (x_i - \bar{X})(y_i - \bar{Y})\;\;,
# $$
# y
# $$
# \hat{\mu_X} = \bar{X}\;\;.
# $$

# %% [markdown]
# Los valores extremos son -1 y 1, para una (anti-)correlación lineal perfecta entre ambas variables.
#
# Ah, entonces $r=0$ significa que las variables no están correlacionadas, ¿no? .... **¡No!**.

# %% [markdown]
# Pero no te preocupes por todos estos detalles si esto no te resulta familiar. Para obtener una idea más intuitiva, analicemos esta imagen, tomada de [Wikipedia](https://en.wikipedia.org/wiki/Pearson_correlation_coefficient):
#
# <img src="https://upload.wikimedia.org/wikipedia/commons/d/d4/Correlation_examples2.svg">
#
# Los números sobre cada subimagen indican el valor del coeficiente de Pearson. **¿Qué te hace pensar esta figura?**

# %% [markdown]
# Calculemos ahora el coeficiente de Pearson para cada par de variables del conjunto de datos de California.

# %%
# The correlation between all pairs of variables is easily computed with Pandas.
corr_matrix = housing.corr()

# %%
# What size do you expect `corr_matrix` to be?
print(corr_matrix.shape)
# Out:
# (9, 9)

# %% [markdown]
# Podemos imprimir la matriz; pero más interesante, la podemos graficar.

# %%
print(corr_matrix)
# Out:
#                     longitude  latitude  housing_median_age  total_rooms  \
# longitude            1.000000 -0.924664           -0.108197     0.044568
# latitude            -0.924664  1.000000            0.011173    -0.036100
# housing_median_age  -0.108197  0.011173            1.000000    -0.361262
# total_rooms          0.044568 -0.036100           -0.361262     1.000000
# total_bedrooms       0.069608 -0.066983           -0.320451     0.930380
# population           0.099773 -0.108785           -0.296244     0.857126
# households           0.055310 -0.071035           -0.302916     0.918484
# median_income       -0.015176 -0.079809           -0.119034     0.198050
# median_house_value  -0.045967 -0.144160            0.105623     0.134153
#
#                     total_bedrooms  population  households  median_income  \
# longitude                 0.069608    0.099773    0.055310      -0.015176
# latitude                 -0.066983   -0.108785   -0.071035      -0.079809
# housing_median_age       -0.320451   -0.296244   -0.302916      -0.119034
# total_rooms               0.930380    0.857126    0.918484       0.198050
# total_bedrooms            1.000000    0.877747    0.979728      -0.007723
# population                0.877747    1.000000    0.907222       0.004834
# households                0.979728    0.907222    1.000000       0.013033
# median_income            -0.007723    0.004834    0.013033       1.000000
# median_house_value        0.049686   -0.024650    0.065843       0.688075
#
#                     median_house_value
# longitude                    -0.045967
# latitude                     -0.144160
# housing_median_age            0.105623
# total_rooms                   0.134153
# total_bedrooms                0.049686
# population                   -0.024650
# households                    0.065843
# median_income                 0.688075
# median_house_value            1.000000

# %%
plt.imshow(corr_matrix)

# Set ticks
xt = plt.xticks(np.arange(9), housing.columns[:-1], rotation=45, ha='right', va='top')
yt = plt.yticks(np.arange(9), housing.columns[:-1], rotation=0, ha='right', va='center')

# Set colorbar
plt.colorbar(label='Pearson CC')

# %% [markdown]
# ## Preguntas

# %% [markdown]
# ***
# Ahora que recorrimos un poco los datos, podemos deternenos un minuto a hacernos unas preguntas.
# No hay respuestas correctas o incorrectas
#
# 1) ¿Qué preguntas pueden responder estos datos?
#
# 2) ¿Cuáles serían los primeros pasos para encontrar respuestas a esas preguntas?
#
# 3) ¿Qué variables serían más relevantes en ese caso?

# %% [markdown]
# ***
# <font size=5>**¿Descanso?**</font>

# %% [markdown]
# ## Visualización

# %% [markdown]
# ¡Una excelente manera de obtener información a partir del conjunto de datos es hacer gráficos!
#
# `Pandas` tiene un lindo *wrapper* a `matplotlib.pyplot`, but intentaremos usar exclusivamente las funciones de `pyplot` (que importamos arriba como `plt`).

# %% [markdown]
# Algunas funciones que podemos probar son:
#
# * `plt.plot` o `plt.scatter` para graficar una variable en función de otra.
# * `plt.hist` o `plt.bar` para ver cómo se distribuyen los valores de una variable.
#
# Y para los que tengan más tendencia a la estadística:
#
# * `plt.boxplot` para comparar las distribuciones de las variables.
# * `plt.violinplot` para hacer lo mismo usando una estimación de *kernel* (que es un algoritmo considerado de machine learning).
#
# Recuerdá que podés obtener la documentación de cada función agregando `?` al nombre. Por ejemplo:

# %%
plt.plot?

# %% [markdown]
# Para ponerlo a prueba, hagamos un gráfico simple de latitud versus longitud.

# %%
# Let's make  simple plot of latitude vs longitude
scatter = plt.scatter(housing.longitude, housing.latitude,alpha=0.2)
#plt.xlabel('Longitude')
#plt.ylabel('Latitude')

# %% [markdown]
# Esta es un gráfico bastante feo. No nos dice mucho. Podemos distinguir la forma de California, pero eso es todo.
#
# <img src="images/01_AED/Map_of_California.png" width=350/>

# %% [markdown]
# ¡Seguro que podemos hacer algo mejor! Estoy seguro de que podés ayudar ...

# %% [markdown]
# ***
# <font size=7>¡Preparen sus teclados!</font>
# <!-- ### Prepare your keyboards! -->
#
#
# * Intentá hacer histogramas de varias variables (las que te parezcan más relevantes). ¿Notás algo que te llame la atención?
# * Probá hacer algunos *scatter plots*.
# * Se puede incluir más variables en un *scatter plot* usando los argumentos `color` (o `c`) y `size` (o `s`). También, podés intentar obtener gráficos más agradables y útiles haciendo que los puntos sean semi-transparentes con el argumento `alpha`.
#
# **Nota**: podés salvar las figuras que quieras con la función `save_fig`, que definimos al principio del notebook.

# %%
plt.scatter(housing.longitude, housing.latitude)
save_fig("bad_visualization_plot")
# Out:
# Saving figure bad_visualization_plot

# %%
#Traigo los nombres de las columnas para tenerlos a mano

housing.columns
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value', 'ocean_proximity'],
#       dtype='object')

# %% [markdown]
# ### Columna 'housing_median_age'

# %%
#Histograma simple

fig1, ax1 = plt.subplots()
ax1.set_title('Housing median age')
ax1.hist(housing['housing_median_age'],bins=10,density=True)

save_fig("housing_median_age_hist")
# Out:
# Saving figure housing_median_age_hist

# %%
#Histograma acumulado

fig1, ax1 = plt.subplots()
ax1.set_title('Housing median age')
ax1.hist(housing['housing_median_age'],bins=10,density=True,cumulative=True)

save_fig("housing_median_age_hist_acumulado")
# Out:
# Saving figure housing_median_age_hist_acumulado

# %%
green_diamond = dict(markerfacecolor='g', marker='D')

fig1, ax1 = plt.subplots()
ax1.set_title('Housing median age')
ax1.boxplot(housing['housing_median_age'],notch=True,meanline=True,flierprops=green_diamond)

save_fig("housing_median_age_boxplot")
# Out:
# Saving figure housing_median_age_boxplot

# %% [markdown]
# ### Columna 'total_rooms'

# %%
#Histograma simple

fig1, ax1 = plt.subplots()
ax1.set_title('Total rooms')
ax1.hist(housing['total_rooms'],bins=6,density=True,color='darkorange')

save_fig("total_rooms_hist")
# Out:
# Saving figure total_rooms_hist

# %%
#Histograma acumulado

fig1, ax1 = plt.subplots()
ax1.set_title('Total rooms')
ax1.hist(housing['total_rooms'],bins=10,density=True,cumulative=True,color='darkorange')

save_fig("total_rooms_hist_acumulado")
# Out:
# Saving figure total_rooms_hist_acumulado

# %%
green_diamond = dict(markerfacecolor='g', marker='D')

fig1, ax1 = plt.subplots()
ax1.set_title('Total rooms')
ax1.boxplot(housing['total_rooms'],notch=True,meanline=True,flierprops=green_diamond)

save_fig("total_rooms_boxplot")
# Out:
# Saving figure total_rooms_boxplot

# %% [markdown]
# ### Columna 'total_bedrooms'

# %%
#Histograma simple

fig1, ax1 = plt.subplots()
ax1.set_title('Total bedrooms')
ax1.hist(housing['total_bedrooms'],bins=6,density=True,color='lightgreen')

save_fig("total_bedrooms_hist")
# Out:
# C:\Users\User\anaconda3\lib\site-packages\numpy\lib\histograms.py:839: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# C:\Users\User\anaconda3\lib\site-packages\numpy\lib\histograms.py:840: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)
# Saving figure total_bedrooms_hist

# %%
#Histograma acumulado

fig1, ax1 = plt.subplots()
ax1.set_title('Total bedrooms')
ax1.hist(housing['total_bedrooms'],bins=10,density=True,cumulative=True,color='lightgreen')

save_fig("total_bedrooms_hist_acumulado")
# Out:
# Saving figure total_bedrooms_hist_acumulado

# %%
green_diamond = dict(markerfacecolor='g', marker='D')

fig1, ax1 = plt.subplots()
ax1.set_title('Total Bedrooms')
ax1.boxplot(housing['total_bedrooms'],notch=True,meanline=True,flierprops=green_diamond)
# Out:
# C:\Users\User\anaconda3\lib\site-packages\matplotlib\cbook\__init__.py:1239: RuntimeWarning: invalid value encountered in less_equal
#   wiskhi = x[x <= hival]
# C:\Users\User\anaconda3\lib\site-packages\matplotlib\cbook\__init__.py:1246: RuntimeWarning: invalid value encountered in greater_equal
#   wisklo = x[x >= loval]
# C:\Users\User\anaconda3\lib\site-packages\matplotlib\cbook\__init__.py:1254: RuntimeWarning: invalid value encountered in less
#   x[x < stats['whislo']],
# C:\Users\User\anaconda3\lib\site-packages\matplotlib\cbook\__init__.py:1255: RuntimeWarning: invalid value encountered in greater
#   x[x > stats['whishi']],
# {'whiskers': [<matplotlib.lines.Line2D at 0x27fde5e1340>,
#   <matplotlib.lines.Line2D at 0x27fde5e1d90>],
#  'caps': [<matplotlib.lines.Line2D at 0x27fde5d5070>,
#   <matplotlib.lines.Line2D at 0x27fde5d5880>],
#  'boxes': [<matplotlib.lines.Line2D at 0x27fde5e1910>],
#  'medians': [<matplotlib.lines.Line2D at 0x27fde5d5b20>],
#  'fliers': [<matplotlib.lines.Line2D at 0x27fde5d5490>],
#  'means': []}

# %% [markdown]
# ### Scatter plot entre 'total_rooms' y  'total_bedrooms'

# %%
plt.title('Total rooms - Total bedrooms')
plt.xlabel('Total rooms')
plt.ylabel('Total bedrooms')

plt.scatter(housing.total_rooms, housing.total_bedrooms)

save_fig("scatter_totalrooms_totalbedrooms_basico")
# Out:
# Saving figure scatter_totalrooms_totalbedrooms_basico

# %%
rng = np.random.RandomState(0)
colors = rng.rand(len(housing['total_bedrooms']))
sizes = 100 * rng.rand(len(housing['total_bedrooms']))



plt.title('Total rooms - Total bedrooms')
plt.scatter(housing.total_rooms, housing.total_bedrooms,c=colors,s=sizes,alpha=0.2,cmap='viridis')

plt.xlabel('Total rooms')
plt.ylabel('Total bedrooms')
plt.colorbar()

save_fig("scatter_totalrooms_totalbedrooms_mejorado")
# Out:
# Saving figure scatter_totalrooms_totalbedrooms_mejorado

# %% [markdown]
# ### Columna 'population'

# %%
#Histograma simple

fig1, ax1 = plt.subplots()
ax1.set_title('Population')
ax1.hist(housing['population'],bins=5,density=True,color='lightgreen')

save_fig("population_hist")
# Out:
# Saving figure population_hist

# %%
green_diamond = dict(markerfacecolor='g', marker='D')

fig1, ax1 = plt.subplots()
ax1.set_title('Population')
ax1.boxplot(housing['population'],notch=True,meanline=True,flierprops=green_diamond)

save_fig("population_boxplot")
# Out:
# Saving figure population_boxplot

# %% [markdown]
# ### Scatter plot entre 'population' y  'total_rooms'

# %%
plt.title('Population - Total rooms')
plt.xlabel('Population')
plt.ylabel('Total rooms')

plt.scatter(housing.population, housing.total_rooms)

save_fig("scatter_population_totalrooms_basico")
# Out:
# Saving figure scatter_population_totalrooms_basico

# %%
rng = np.random.RandomState(0)
colors = rng.rand(len(housing['total_rooms']))
sizes = 100 * rng.rand(len(housing['total_rooms']))



plt.title('Population - Total rooms')
plt.scatter(housing.population, housing.total_rooms,c=colors,s=sizes,alpha=0.2,cmap='viridis')

plt.xlabel('Population')
plt.ylabel('Total rooms')
plt.colorbar()

save_fig("scatter_population_totalrooms_mejorado")
# Out:
# Saving figure scatter_population_totalrooms_mejorado

# %% [markdown]
# ### Scatter plot entre 'population' y  'total_bedrooms'

# %%
plt.title('Population - Total bedbedrooms')
plt.xlabel('Population')
plt.ylabel('Total bedrooms')


plt.scatter(housing.population, housing.total_bedrooms)

save_fig("scatter_population_totalbedrooms_basico")
# Out:
# Saving figure scatter_population_totalbedrooms_basico

# %%
rng = np.random.RandomState(0)
colors = rng.rand(len(housing['total_bedrooms']))
sizes = 100 * rng.rand(len(housing['total_bedrooms']))



plt.title('Population - Total bedrooms')
plt.scatter(housing.population, housing.total_bedrooms,c=colors,s=sizes,alpha=0.2,cmap='viridis')

plt.xlabel('Population')
plt.ylabel('Total bedrooms')
plt.colorbar()

save_fig("scatter_population_totalbedrooms_mejorado")
# Out:
# Saving figure scatter_population_totalbedrooms_mejorado

# %% [markdown]
# ### Columna 'households'

# %%
#Histograma simple

fig1, ax1 = plt.subplots()
ax1.set_title('Households')
ax1.hist(housing['households'],bins=5,density=True,color='lightcoral')

save_fig("household_hist")
# Out:
# Saving figure household_hist

# %% [markdown]
# ### Columna 'median_income'

# %%
#Histograma simple

fig1, ax1 = plt.subplots()
ax1.set_title('Median Income')
ax1.hist(housing['median_income'],bins=10,density=True,color='chocolate')

save_fig("median_income_hist")
# Out:
# Saving figure median_income_hist

# %%
green_diamond = dict(markerfacecolor='g', marker='D')

fig1, ax1 = plt.subplots()
ax1.set_title('Median income')
ax1.boxplot(housing['median_income'],notch=True,meanline=True,flierprops=green_diamond)

save_fig("median_income_boxplot")
# Out:
# Saving figure median_income_boxplot

# %% [markdown]
# ### Columna 'median_house_value'

# %%
#Histograma simple

fig1, ax1 = plt.subplots()
ax1.set_title('Median House Value')
ax1.hist(housing['median_house_value'],bins=10,density=True,color='khaki')

save_fig("median_house_value_hist")
# Out:
# Saving figure median_house_value_hist

# %%
green_diamond = dict(markerfacecolor='g', marker='D')

fig1, ax1 = plt.subplots()
ax1.set_title('Median house value')
ax1.boxplot(housing['median_house_value'],notch=True,meanline=True,flierprops=green_diamond)

save_fig("median_house_value_boxplot")
# Out:
# Saving figure median_house_value_boxplot

# %% [markdown]
# ### Scatter plot entre 'median_income' y  'median_house_value'

# %%
plt.title('Median income - Median house value')
plt.xlabel('Median income')
plt.ylabel('Median house value')

plt.scatter(housing.median_income, housing.median_house_value)

save_fig("scatter_medianincome_medianhousevalue_basico")
# Out:
# Saving figure scatter_medianincome_medianhousevalue_basico

# %%
rng = np.random.RandomState(0)
colors = rng.rand(len(housing['median_income']))
sizes = 100 * rng.rand(len(housing['median_income']))



plt.title('Median income - Median house value')
plt.scatter(housing.median_income, housing.median_house_value,c=colors,s=sizes,alpha=0.2,cmap='viridis')

plt.xlabel('Median income')
plt.ylabel('Median house value')
plt.colorbar()

save_fig("scatter_medianincome_medianhousevalue_mejorado")
# Out:
# Saving figure scatter_medianincome_medianhousevalue_mejorado

# %% [markdown]
# ## Graficos Seaborn

# %% [markdown]
# ### Columna 'ocean_proximity'
#
# Al ser una columna con datos categoricos elijo utilizar la libreria seaborn

# %%
import seaborn as sns

# %%
plt.title('Ocean proximity')


plt.xlabel('Category')
plt.ylabel('Count')

sns.countplot(housing['ocean_proximity'])

save_fig("ocean_proximity")
# Out:
# Saving figure ocean_proximity

# %%
near_bay = housing[housing['ocean_proximity']=='NEAR BAY']

near_bay.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
housing.groupby('ocean_proximity')['median_house_value'].mean()
# Out:
# ocean_proximity
# <1H OCEAN     240084.285464
# INLAND        124805.392001
# ISLAND        380440.000000
# NEAR BAY      259212.311790
# NEAR OCEAN    249433.977427
# Name: median_house_value, dtype: float64

# %%
#Matriz de correlacion

plt.figure(figsize=(12,8))

plt.title('Matriz de correlacion')

corr_new = housing.corr()
cmap = sns.diverging_palette(230, 20, as_cmap=True)
sns.heatmap(corr_new,cmap=cmap)

save_fig("correlation matrix")
# Out:
# Saving figure correlation matrix

# %%
#KDE para 'housing_median_age'

plt.title('KDE housing media age')

sns.kdeplot(data=housing['housing_median_age'],color='r')

save_fig("KDE_housing_media_age")
# Out:
# Saving figure KDE_housing_media_age

# %%
#KDE para 'total_rooms'

plt.title('KDE total rooms')

sns.kdeplot(data=housing['total_rooms'],color='g')

save_fig("KDE_total_rooms")
# Out:
# Saving figure KDE_total_rooms

# %%
#KDE para 'total_bedrooms'

plt.title('KDE total bedrooms')

sns.kdeplot(data=housing['total_bedrooms'],color='b')

save_fig("KDE_total_bedrooms")
# Out:
# Saving figure KDE_total_bedrooms

# %%
#KDE para 'population'

plt.title('KDE population')

sns.kdeplot(data=housing['population'],color='coral')

save_fig("KDE_population")
# Out:
# Saving figure KDE_population

# %%
#KDE para 'median_income'

plt.title('KDE median income')

sns.kdeplot(data=housing['median_income'],color='lime')

save_fig("KDE_median_income")
# Out:
# Saving figure KDE_median_income

# %%
#KDE para 'median_house_value'

plt.title('KDE median house value')

sns.kdeplot(data=housing['median_house_value'],color='orchid')

save_fig("KDE_median_house_value")
# Out:
# Saving figure KDE_median_house_value

# %% [markdown]
# ## Matriz de correlacion - Diagonal

# %%
from matplotlib import cm

mask =  np.tri(corr_matrix.shape[0], k=-1)
A = np.ma.array(corr_matrix, mask=mask) 
cmap = cm.get_cmap('viridis', 10)
cmap.set_bad('w')

# Set ticks
xt = plt.xticks(np.arange(9), housing.columns[:-1], rotation=45, ha='right', va='top')
yt = plt.yticks(np.arange(9), housing.columns[:-1], rotation=0, ha='right', va='center')

# Set colorbar
plt.imshow(A, interpolation="nearest", cmap=cmap)
plt.grid(True)
plt.colorbar(label='Pearson CC')
plt.show()

# %% [markdown]
# Algunas observaciones sencillas del Analisis Exploratorio inicial mediante graficos:
#
# a) Los valores de 'total_rooms' y 'total_bedrooms' no son valores que correspondan a una casa particular. Como se indico al comienzo del notebook cada fila corresponde a un distrito de California, por este motivo estos valores son tan elevados y se confirma visualmente por medio de los histogramas.
#
# b) Observando el boxplot de 'total_rooms' 'population' y 'median_income' se ve una cantidad siginificado de outliers
#
# c) Mediante un scatterplot se observa una relacion aproximadamente lineal (aprox 5:1) entre 'total_rooms'-'total_bedrooms'
#
# d) Mediante un scatterplot se observa una relacion aproximadamente lineal entre 'population'-'total_rooms' y 'population'- 'total_bedrooms'. Ademas se observan un par de valores que salen de esta relacion aproximadamente lineal
#
# d) Observando los valores del histograma de 'median_house_value' y el scatterplot de 'median_income'-'median_house_value' se observa un maximo 'median_house_value'de 500000 ¿Esto es correcto o por algun motivo los valores de casas superiores a 500000 fueron recortados a ese valor?
#
# f) De la columna 'ocean_proximity' se observa que la categoria '<1H OCEAN' es predominante en cantidad de registros
#
# g) De la matriz de correlacion se observa una fuerte correlacion positiva de las variables 'total_rooms', 'total_bedrooms','population' y 'households' y una moderada correlacion positiva entre 'median_income' y 'median_house_value'
